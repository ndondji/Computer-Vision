# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
with open('df_time_tshisola_C103_DG4.obj', 'rb') as f:
    lyingData = pickle.load(f)

# %%
print (lyingData)
# Out:
# detection_classes    pig lying  pig not lying
# detection_time
# 2018-10-02 13:15:51          3             15
# 2018-10-02 13:15:54          3             16
# 2018-10-02 13:15:56          1             16
# 2018-10-02 13:15:58          0             15
# 2018-10-02 13:15:59          1             18
# 2018-10-02 13:16:01          2             14
# 2018-10-02 13:16:04          7             11
# 2018-10-02 13:16:12          2             16
# 2018-10-02 13:16:14          1             17
# 2018-10-02 13:16:23          6              9
# 2018-10-02 13:16:26          7             26
# 2018-10-02 14:15:58          9              7
# 2018-10-02 14:16:01         11              6
# 2018-10-02 14:16:09         16              1
# 2018-10-02 14:16:10         10              6
# 2018-10-02 14:16:11         11              6
# 2018-10-02 14:16:12         12              4
# 2018-10-02 14:16:13         10              6
# 2018-10-02 14:16:20         10              9
# ...

# %%
lyingData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22242 entries, 2018-10-02 13:15:51 to 2018-12-30 23:01:37
# Data columns (total 2 columns):
# pig lying        22242 non-null int64
# pig not lying    22242 non-null int64
# dtypes: int64(2)
# memory usage: 521.3+ KB

# %%
lyingData.columns = lyingData.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
lyingData["number_of_pigs"] = lyingData["pig_lying"] + lyingData["pig_not_lying"]
lyingData.head()
# Out:
# detection_classes    pig_lying  pig_not_lying  number_of_pigs
# detection_time
# 2018-10-02 13:15:51          3             15              18
# 2018-10-02 13:15:54          3             16              19
# 2018-10-02 13:15:56          1             16              17
# 2018-10-02 13:15:58          0             15              15
# 2018-10-02 13:15:59          1             18              19

# %%
sample_index = np.arange(0, 22241, 100)
sample_index
# Out:
# array([    0,   100,   200,   300,   400,   500,   600,   700,   800,
#          900,  1000,  1100,  1200,  1300,  1400,  1500,  1600,  1700,
#         1800,  1900,  2000,  2100,  2200,  2300,  2400,  2500,  2600,
#         2700,  2800,  2900,  3000,  3100,  3200,  3300,  3400,  3500,
#         3600,  3700,  3800,  3900,  4000,  4100,  4200,  4300,  4400,
#         4500,  4600,  4700,  4800,  4900,  5000,  5100,  5200,  5300,
#         5400,  5500,  5600,  5700,  5800,  5900,  6000,  6100,  6200,
#         6300,  6400,  6500,  6600,  6700,  6800,  6900,  7000,  7100,
#         7200,  7300,  7400,  7500,  7600,  7700,  7800,  7900,  8000,
#         8100,  8200,  8300,  8400,  8500,  8600,  8700,  8800,  8900,
#         9000,  9100,  9200,  9300,  9400,  9500,  9600,  9700,  9800,
#         9900, 10000, 10100, 10200, 10300, 10400, 10500, 10600, 10700,
#        10800, 10900, 11000, 11100, 11200, 11300, 11400, 11500, 11600,
# ...

# %%
sample_lyingData = lyingData.number_of_pigs[sample_index]
np.mean(lyingData.number_of_pigs)
# Out:
# 17.714908731229205

# %%
sample_lyingData.head()
# Out:
# detection_time
# 2018-10-02 13:15:51    18
# 2018-10-02 22:15:56    16
# 2018-10-03 08:01:09    17
# 2018-10-03 17:01:26    19
# 2018-10-04 03:01:11    28
# Name: number_of_pigs, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.plot(sample_lyingData)
plt.title('Number of pigs(every 100th data point)')
plt.grid(True)
plt.show()
